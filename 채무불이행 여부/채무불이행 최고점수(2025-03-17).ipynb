# %%
import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split, KFold
from imblearn.over_sampling import SMOTE

gpus = tf.config.experimental.list_physical_devices("GPU")
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_memory_growth(gpus, True)
    print("GPU 환경에서 실행됩니다.")
else:
    print("GPU가 감지되지않습니다. CPU환경에서 실행됩니다.")
# Out:
# GPU가 감지되지않습니다. CPU환경에서 실행됩니다.

# %%
import os
file_path = os.getcwd()
train_path = os.path.join(file_path, "데이터셋", "train.csv")
test_path = os.path.join(file_path, "데이터셋", "test.csv")
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)

# %%
def preprocess(df):
    df = df.copy()
    def year(x):
        return "".join(v.replace("이상", "").replace("년", "") for v in x.split(" "))

    def year1(x):
        return "".join(v.replace('1미만', "0") for v in x.split(" "))
    
    df["신용 거래 연수"] = df["신용 거래 연수"].astype(int)
    
    
    cols = (["주거 형태","대출 목적", "대출 상환 기간"])
    for c in cols:
        lb = LabelEncoder()
        lb.fit(df[c].values)
        df[c] = lb.transform(list(df[c].values))
        df[c] = df[c].astype(int)

 
    df["현재 직장 근속 연수"] = df["현재 직장 근속 연수"].apply(year)
    df["현재 직장 근속 연수"] = df["현재 직장 근속 연수"].apply(year1).astype(int)
    df["현재 대출 잔액"] = df["현재 대출 잔액"].where((df["현재 대출 잔액"] > 0), np.nan)
    df["현재 대출 잔액"] = df["현재 대출 잔액"].fillna(df["현재 대출 잔액"].median())
    df["최대 신용한도"] = df["최대 신용한도"].where((df["최대 신용한도"] > 0), np.nan)
    df["최대 신용한도"] = df["최대 신용한도"].fillna(df["최대 신용한도"].median())
    df["대출액+신용액"] = df["현재 대출 잔액"] + df["현재 미상환 신용액"]
    df["상환액 분위"] = pd.qcut(df["대출액+신용액"], 5, labels = [1,2,3,4,5], duplicates = "drop").astype(int)

    df["신용거래분위"] = pd.qcut(df["신용 거래 연수"], 5, labels = [1,2,3,4,5], duplicates = "drop").astype(int)
    df["신용점수분위"] = pd.qcut(df["신용 점수"], 5, labels = [1,2,3,4,5], duplicates= "drop").astype(int)

    df["연간소득분위"] = pd.qcut(df["연간 소득"], 5, labels = [1,2,3,4,5], duplicates = "drop").astype(int)
    df["개설된_신용계좌_분위수"] = pd.qcut(df["개설된 신용계좌 수"], 5, labels = [1,2,3,4,5], duplicates = "drop").astype(int)
    df["대출잔액 분위수"] = pd.qcut(df["현재 대출 잔액"], 5, labels = [1,2,3,4,5], duplicates= "drop").astype(int)
    df["직장근속연수 분위수"] = pd.qcut(df["현재 직장 근속 연수"], 7, labels = [1,2,3,4,5], duplicates= "drop").astype(int)
    

    df["신용한도vs대출잔액"] = (df["현재 대출 잔액"] + df["현재 미상환 신용액"] )  / ((df["최대 신용한도"] * df["개설된 신용계좌 수"]))* 100

    df["DTI"] = ((df["현재 대출 잔액"] + df["현재 미상환 신용액"]) / df["연간 소득"]) * 100
    df["DTR"] = ((df["월 상환 부채액"] + 1) / (df["연간 소득"] / 12)) * 100

    df["DTI분위"] = pd.qcut(df["DTI"], 5, labels = [1,2,3,4,5], duplicates= "drop").astype(int)
    df["DTR분위"] = pd.qcut(df["DTR"], 5, labels = [1,2,3,4,5], duplicates= "drop").astype(int)
    df["DBI"] = (df["DTI"] + df["DTR"]) / 2
    df["DRS"] = (df["DTI"] * df["DTR"])

    df["신용위험"] = ((df["개설된_신용계좌_분위수"] >= 3) & (df["신용점수분위"] <= 3) & (df["신용거래분위"] <= 3)).astype(int)
    df["소득위험"] = ((df["직장근속연수 분위수"] < 3) & (df["연간소득분위"] < 3)).astype(int)
    df["대출위험"] = ((df["상환액 분위"] > 3) & (df["DTR분위"] < 3)).astype(int)
    df["파산위험"] = ((df["신용 문제 발생 횟수"] > 0) & ((df["개인 파산 횟수"] > 0) | (df["체납 세금 압류 횟수"] > 0))).astype(int)
    df["부채통합위험"] = ((df["대출 목적"] == 4) & (df["DTI분위"] > 3)).astype(int)
    df["부채통합위험2"] = ((df["대출 목적"] == 4) & (df["신용위험"] == 1)).astype(int)
    

    df["위험분자"] = df["신용위험"] + df["소득위험"] + df["대출위험"] + df["파산위험"] + df["부채통합위험"] + df["부채통합위험2"]


    df["근속연수vs거래연수"] = (df["현재 직장 근속 연수"] / df["신용 거래 연수"]) * 100


    #df["위험도 점수"] = df["신용점수분위"] - df["상환액 분위"]
    #df["위험도 점수2"] = df["신용거래분위"] - df["개설된_신용계좌_분위수"]
    #df["위험도 점수3"] = df["직장근속연수 분위수"] - df["대출잔액 분위수"]

    #df["문제 발생 점수"] = df["신용 문제 발생 횟수"] + df["개인 파산 횟수"] + df["체납 세금 압류 횟수"]


    #df["VIP"] = ((df["개설된_신용계좌_분위수"] > 3) & (df["신용점수분위"] > 3)).astype(int)


    df["개설계좌vs연체이후개월수"] = df["개설된 신용계좌 수"] / (df["마지막 연체 이후 경과 개월 수"] + 1) * 100

    #df["고위험 대출목적"] = (df["대출 목적"] == 4).astype(int)

    목적별_위험 = df.groupby("대출 목적")["대출 상환 기간"].agg("mean") * 100
    #df["목적별 위험분자 지수"] = df["대출 목적"].map(목적별_위험)
    #df["목적별 위험분자 지수"] = df["목적별 위험분자 지수"].astype(float)
    


    신용거래 = df.groupby("개설된 신용계좌 수")["신용 거래 연수"].agg("mean")
    #df["신용거래연수_개설신용계좌"] = df["개설된 신용계좌 수"].map(신용거래)
    신용대출 = df.groupby("개설된 신용계좌 수")["현재 대출 잔액"].agg("mean")
    #df["신용계좌vs대출잔액"] = df["개설된 신용계좌 수"].map(신용대출)
    #df["신용계좌vs대출잔액"] = df["신용계좌vs대출잔액"] / 10000
    
    bankcount_purpose = df.groupby("대출 목적")["개설된 신용계좌 수"].agg("median")
    purpose_bankcount = df.groupby("개설된 신용계좌 수")["연간 소득"].agg("median")
    #df["계좌수별_소득"] = df["개설된 신용계좌 수"].map(purpose_bankcount)
    #df["계좌수별_소득"] = df["계좌수별_소득"].astype(int)  

    df = df.drop(["대출액+신용액", "DTR분위", "상환액 분위", "DTI분위"], axis = 1)
    
    return df

train = preprocess(train_df)
test = preprocess(test_df)
train.head()
# Out:
#            UID  주거 형태      연간 소득  현재 직장 근속 연수  체납 세금 압류 횟수  개설된 신용계좌 수  \
# 0  TRAIN_00000      1  1941337.5           10          0.0           9
# 1  TRAIN_00001      0  1979505.0           10          0.0           5
# 2  TRAIN_00002      0  1356381.0            4          0.0          12
# 3  TRAIN_00003      0  1049017.5            6          0.0          15
# 4  TRAIN_00004      0  4320217.5            2          0.0          11
#
#    신용 거래 연수   최대 신용한도  신용 문제 발생 횟수  마지막 연체 이후 경과 개월 수  ...          DRS  신용위험  \
# 0        13  400597.5            0                 24  ...   172.848896     0
# 1        15  360679.5            0                 11  ...   815.630522     0
# 2        18  491770.5            1                 74  ...   563.229756     0
# 3        14  411546.0            1                 22  ...  2300.998057     0
# 4        26  895288.5            0                 32  ...    46.824188     0
#
#    소득위험  대출위험  파산위험  부채통합위험  부채통합위험2  위험분자  근속연수vs거래연수  개설계좌vs연체이후개월수
# 0     0     0     0       0        0     0   76.923077      36.000000
# 1     0     0     0       1        0     1   66.666667      41.666667
# 2     1     0     1       1        0     3   22.222222      16.000000
# 3     0     0     1       1        0     2   42.857143      65.217391
# 4     0     1     0       0        0     1    7.692308      33.333333
#
# [5 rows x 38 columns]

# %%
plt.rc("font", family = "NanumGothic")
plt.figure(figsize = (12,8))
sns.distplot(train["신용 점수"], color = "b", bins = 100, hist_kws = {"alpha": 0.3})
# Out:
# C:\Users\yunju\AppData\Local\Temp\ipykernel_83768\235274021.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(train["신용 점수"], color = "b", bins = 100, hist_kws = {"alpha": 0.3})
# <Axes: xlabel='신용 점수', ylabel='Density'>

# %%
target = train["채무 불이행 여부"]
uid = test["UID"]

train = train.drop(["채무 불이행 여부", "UID"], axis = 1)
test = test.drop("UID", axis = 1)

# %%
from scipy.stats import boxcox
from scipy.special import boxcox1p

cols = ["최대 신용한도", "연간 소득", "월 상환 부채액", "현재 대출 잔액", "현재 미상환 신용액", "근속연수vs거래연수", "신용한도vs대출잔액", "신용 점수", "DTI", "DTR", "개설계좌vs연체이후개월수", "DBI", "DRS", "개설된 신용계좌 수", "신용 거래 연수"]
for c in cols:
    train[c] = train[c].where((train[c] > 0), np.nan)
    test[c] = test[c].where((test[c] > 0), np.nan)
    train[c] = train[c].fillna(train[c].median())
    test[c] = test[c].fillna(test[c].median())
    
    train[c], l = boxcox(train[c])
    test[c]= boxcox(test[c], lmbda = l)
print(train[cols].info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   최대 신용한도        10000 non-null  float64
#  1   연간 소득          10000 non-null  float64
#  2   월 상환 부채액       10000 non-null  float64
#  3   현재 대출 잔액       10000 non-null  float64
#  4   현재 미상환 신용액     10000 non-null  float64
#  5   근속연수vs거래연수     10000 non-null  float64
#  6   신용한도vs대출잔액     10000 non-null  float64
#  7   신용 점수          10000 non-null  float64
#  8   DTI            10000 non-null  float64
#  9   DTR            10000 non-null  float64
#  10  개설계좌vs연체이후개월수  10000 non-null  float64
#  11  DBI            10000 non-null  float64
#  12  DRS            10000 non-null  float64
#  13  개설된 신용계좌 수     10000 non-null  float64
#  14  신용 거래 연수       10000 non-null  float64
# dtypes: float64(15)
# memory usage: 1.1 MB
# None

# %%
train.hist(figsize = (12,8),bins = 50);

# %%
from sklearn.preprocessing import MinMaxScaler

minmax = MinMaxScaler()
X_scaled = minmax.fit_transform(train)
test_scaled = minmax.transform(test)
"""
standard = StandardScaler()
X_scaled = standard.fit_transform(train)
test_scaled = standard.transform(test)
"""
# Out:
# '\nstandard = StandardScaler()\nX_scaled = standard.fit_transform(train)\ntest_scaled = standard.transform(test)\n'

# %%
smote = SMOTE(random_state= 42)
X_resampled, y_resampled = smote.fit_resample(X_scaled, target)

# %%
all_history = []
kf = KFold(n_splits= 5, shuffle= True, random_state= 42)
fold = 1
roc_auc_scores = []

for train_index, valid_index in kf.split(X_resampled):
    X_train_fold, X_valid_fold = X_resampled[train_index], X_resampled[valid_index]
    y_train_fold, y_valid_fold = y_resampled[train_index], y_resampled[valid_index]
    print(f"Fold {fold} 시작!")

    model = tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation= "relu", input_shape = (X_train_fold.shape[1],)),
        tf.keras.layers.Dropout(0.30),
        tf.keras.layers.Dense(64, activation = "relu"),
        tf.keras.layers.Dropout(0.30),
        tf.keras.layers.Dense(32, activation = "relu"),
        tf.keras.layers.Dense(1, activation = "sigmoid")
    ])

    model.compile(
        optimizer = tf.keras.optimizers.Adam(learning_rate= 1e-5),
        loss = "binary_crossentropy",
        metrics = ["accuracy"]
    )

    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor = "val_loss",
        patience = 5,
        min_delta = 0.001,
        restore_best_weights = True
    )

    history = model.fit(
        X_train_fold, y_train_fold,
        validation_data = (X_valid_fold, y_valid_fold),
        epochs = 100,
        callbacks = early_stop,
        verbose = 1,
    )

    all_history.append(history.history)
    y_valid_pred = model.predict(X_valid_fold).ravel()
    roc_auc = roc_auc_score(y_valid_fold, y_valid_pred)
    print(f"FOLD {fold} ROC-AUC SCORE {roc_auc:.4f}")
    roc_auc_scores.append(roc_auc)
    fold += 1

print(f"교차 검증 ROC-AUC 평균 점수 {np.mean(roc_auc_scores):.4f}")

for i, history in enumerate(all_history):
    epochs = range(1, len(history["loss"]) + 1)
    plt.figure(figsize = (12,4))
    plt.subplot(1,2,1)
    plt.plot(epochs, history["accuracy"], label = "Train Accuracy")
    plt.plot(epochs, history["val_accuracy"], label = "Validation Accuracy")
    plt.title(f"Fold {i+1} Accuracy")
    plt.xlabel("Epochs")
    plt.ylabel("Accuracy")
    plt.legend()

    plt.subplot(1,2,2)
    plt.plot(epochs, history["loss"], label = "Train Loss")
    plt.plot(epochs, history["val_loss"], label = "Validation Loss")
    plt.title(f"Fold {i+1} Loss")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# Fold 1 시작!
# Epoch 1/100
# 330/330 [==============================] - 2s 4ms/step - loss: 0.6975 - accuracy: 0.5059 - val_loss: 0.6889 - val_accuracy: 0.5577
# Epoch 2/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6913 - accuracy: 0.5235 - val_loss: 0.6841 - val_accuracy: 0.5964
# Epoch 3/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6903 - accuracy: 0.5344 - val_loss: 0.6801 - val_accuracy: 0.6077
# Epoch 4/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6859 - accuracy: 0.5466 - val_loss: 0.6761 - val_accuracy: 0.6149
# Epoch 5/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6821 - accuracy: 0.5649 - val_loss: 0.6720 - val_accuracy: 0.6241
# Epoch 6/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6796 - accuracy: 0.5657 - val_loss: 0.6681 - val_accuracy: 0.6347
# Epoch 7/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6768 - accuracy: 0.5797 - val_loss: 0.6644 - val_accuracy: 0.6449
# Epoch 8/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6741 - accuracy: 0.5821 - val_loss: 0.6608 - val_accuracy: 0.6495
# Epoch 9/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6711 - accuracy: 0.5961 - val_loss: 0.6570 - val_accuracy: 0.6498
# Epoch 10/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6661 - accuracy: 0.6104 - val_loss: 0.6532 - val_accuracy: 0.6521
# Epoch 11/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6645 - accuracy: 0.6067 - val_loss: 0.6496 - val_accuracy: 0.6567
# Epoch 12/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6639 - accuracy: 0.6067 - val_loss: 0.6465 - val_accuracy: 0.6582
# Epoch 13/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6609 - accuracy: 0.6135 - val_loss: 0.6433 - val_accuracy: 0.6574
# Epoch 14/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6594 - accuracy: 0.6126 - val_loss: 0.6401 - val_accuracy: 0.6590
# Epoch 15/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6565 - accuracy: 0.6166 - val_loss: 0.6372 - val_accuracy: 0.6586
# Epoch 16/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6556 - accuracy: 0.6165 - val_loss: 0.6348 - val_accuracy: 0.6605
# Epoch 17/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6519 - accuracy: 0.6241 - val_loss: 0.6323 - val_accuracy: 0.6620
# Epoch 18/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6521 - accuracy: 0.6234 - val_loss: 0.6303 - val_accuracy: 0.6616
# Epoch 19/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6527 - accuracy: 0.6194 - val_loss: 0.6287 - val_accuracy: 0.6631
# Epoch 20/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6502 - accuracy: 0.6269 - val_loss: 0.6270 - val_accuracy: 0.6624
# Epoch 21/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6482 - accuracy: 0.6281 - val_loss: 0.6257 - val_accuracy: 0.6643
# Epoch 22/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6460 - accuracy: 0.6325 - val_loss: 0.6241 - val_accuracy: 0.6627
# Epoch 23/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6449 - accuracy: 0.6318 - val_loss: 0.6228 - val_accuracy: 0.6646
# Epoch 24/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6464 - accuracy: 0.6280 - val_loss: 0.6216 - val_accuracy: 0.6681
# Epoch 25/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6457 - accuracy: 0.6335 - val_loss: 0.6208 - val_accuracy: 0.6662
# Epoch 26/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6443 - accuracy: 0.6369 - val_loss: 0.6199 - val_accuracy: 0.6662
# Epoch 27/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6427 - accuracy: 0.6359 - val_loss: 0.6190 - val_accuracy: 0.6669
# Epoch 28/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6413 - accuracy: 0.6397 - val_loss: 0.6180 - val_accuracy: 0.6688
# Epoch 29/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6432 - accuracy: 0.6355 - val_loss: 0.6174 - val_accuracy: 0.6684
# Epoch 30/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6443 - accuracy: 0.6354 - val_loss: 0.6169 - val_accuracy: 0.6696
# Epoch 31/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6404 - accuracy: 0.6449 - val_loss: 0.6162 - val_accuracy: 0.6696
# Epoch 32/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6397 - accuracy: 0.6381 - val_loss: 0.6156 - val_accuracy: 0.6700
# Epoch 33/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6370 - accuracy: 0.6437 - val_loss: 0.6149 - val_accuracy: 0.6707
# Epoch 34/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6384 - accuracy: 0.6451 - val_loss: 0.6145 - val_accuracy: 0.6711
# Epoch 35/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6368 - accuracy: 0.6426 - val_loss: 0.6139 - val_accuracy: 0.6719
# Epoch 36/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6400 - accuracy: 0.6361 - val_loss: 0.6136 - val_accuracy: 0.6715
# Epoch 37/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6361 - accuracy: 0.6457 - val_loss: 0.6131 - val_accuracy: 0.6730
# Epoch 38/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6354 - accuracy: 0.6474 - val_loss: 0.6128 - val_accuracy: 0.6730
# Epoch 39/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6356 - accuracy: 0.6408 - val_loss: 0.6123 - val_accuracy: 0.6737
# Epoch 40/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6344 - accuracy: 0.6468 - val_loss: 0.6119 - val_accuracy: 0.6722
# Epoch 41/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6322 - accuracy: 0.6462 - val_loss: 0.6114 - val_accuracy: 0.6707
# Epoch 42/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6357 - accuracy: 0.6458 - val_loss: 0.6111 - val_accuracy: 0.6719
# Epoch 43/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6338 - accuracy: 0.6457 - val_loss: 0.6109 - val_accuracy: 0.6745
# Epoch 44/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6341 - accuracy: 0.6465 - val_loss: 0.6105 - val_accuracy: 0.6734
# Epoch 45/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6484 - val_loss: 0.6101 - val_accuracy: 0.6741
# Epoch 46/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6341 - accuracy: 0.6489 - val_loss: 0.6100 - val_accuracy: 0.6760
# Epoch 47/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6352 - accuracy: 0.6474 - val_loss: 0.6099 - val_accuracy: 0.6772
# Epoch 48/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6310 - accuracy: 0.6452 - val_loss: 0.6096 - val_accuracy: 0.6753
# Epoch 49/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6328 - accuracy: 0.6497 - val_loss: 0.6093 - val_accuracy: 0.6764
# Epoch 50/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6318 - accuracy: 0.6483 - val_loss: 0.6089 - val_accuracy: 0.6779
# Epoch 51/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6315 - accuracy: 0.6499 - val_loss: 0.6088 - val_accuracy: 0.6775
# Epoch 52/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6303 - accuracy: 0.6522 - val_loss: 0.6086 - val_accuracy: 0.6779
# Epoch 53/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6324 - accuracy: 0.6471 - val_loss: 0.6085 - val_accuracy: 0.6764
# Epoch 54/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6324 - accuracy: 0.6507 - val_loss: 0.6083 - val_accuracy: 0.6756
# Epoch 55/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6294 - accuracy: 0.6503 - val_loss: 0.6081 - val_accuracy: 0.6768
# Epoch 56/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6322 - accuracy: 0.6515 - val_loss: 0.6080 - val_accuracy: 0.6764
# 83/83 [==============================] - 0s 2ms/step
# FOLD 1 ROC-AUC SCORE 0.7339
# Fold 2 시작!
# Epoch 1/100
# 330/330 [==============================] - 2s 4ms/step - loss: 0.7050 - accuracy: 0.5013 - val_loss: 0.6930 - val_accuracy: 0.5078
# Epoch 2/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6983 - accuracy: 0.5092 - val_loss: 0.6883 - val_accuracy: 0.5423
# Epoch 3/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6931 - accuracy: 0.5168 - val_loss: 0.6844 - val_accuracy: 0.5567
# Epoch 4/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6880 - accuracy: 0.5419 - val_loss: 0.6805 - val_accuracy: 0.5723
# Epoch 5/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6820 - accuracy: 0.5576 - val_loss: 0.6764 - val_accuracy: 0.6000
# Epoch 6/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6827 - accuracy: 0.5543 - val_loss: 0.6731 - val_accuracy: 0.6144
# Epoch 7/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6784 - accuracy: 0.5666 - val_loss: 0.6695 - val_accuracy: 0.6323
# Epoch 8/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6765 - accuracy: 0.5750 - val_loss: 0.6659 - val_accuracy: 0.6414
# Epoch 9/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6727 - accuracy: 0.5831 - val_loss: 0.6624 - val_accuracy: 0.6425
# Epoch 10/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6698 - accuracy: 0.5916 - val_loss: 0.6590 - val_accuracy: 0.6463
# Epoch 11/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6649 - accuracy: 0.6054 - val_loss: 0.6553 - val_accuracy: 0.6490
# Epoch 12/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6630 - accuracy: 0.6070 - val_loss: 0.6524 - val_accuracy: 0.6490
# Epoch 13/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6621 - accuracy: 0.6098 - val_loss: 0.6496 - val_accuracy: 0.6486
# Epoch 14/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6603 - accuracy: 0.6092 - val_loss: 0.6467 - val_accuracy: 0.6528
# Epoch 15/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6564 - accuracy: 0.6119 - val_loss: 0.6443 - val_accuracy: 0.6543
# Epoch 16/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6524 - accuracy: 0.6248 - val_loss: 0.6418 - val_accuracy: 0.6535
# Epoch 17/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6508 - accuracy: 0.6244 - val_loss: 0.6397 - val_accuracy: 0.6524
# Epoch 18/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6497 - accuracy: 0.6248 - val_loss: 0.6376 - val_accuracy: 0.6516
# Epoch 19/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6488 - accuracy: 0.6296 - val_loss: 0.6357 - val_accuracy: 0.6505
# Epoch 20/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6462 - accuracy: 0.6290 - val_loss: 0.6343 - val_accuracy: 0.6520
# Epoch 21/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6447 - accuracy: 0.6328 - val_loss: 0.6329 - val_accuracy: 0.6516
# Epoch 22/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6457 - accuracy: 0.6253 - val_loss: 0.6317 - val_accuracy: 0.6516
# Epoch 23/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6455 - accuracy: 0.6272 - val_loss: 0.6309 - val_accuracy: 0.6535
# Epoch 24/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6416 - accuracy: 0.6395 - val_loss: 0.6297 - val_accuracy: 0.6550
# Epoch 25/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6416 - accuracy: 0.6394 - val_loss: 0.6290 - val_accuracy: 0.6565
# Epoch 26/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6390 - accuracy: 0.6405 - val_loss: 0.6281 - val_accuracy: 0.6565
# Epoch 27/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6395 - accuracy: 0.6426 - val_loss: 0.6277 - val_accuracy: 0.6554
# Epoch 28/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6376 - accuracy: 0.6442 - val_loss: 0.6270 - val_accuracy: 0.6546
# Epoch 29/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6378 - accuracy: 0.6398 - val_loss: 0.6265 - val_accuracy: 0.6550
# Epoch 30/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6361 - accuracy: 0.6429 - val_loss: 0.6257 - val_accuracy: 0.6588
# Epoch 31/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6360 - accuracy: 0.6462 - val_loss: 0.6252 - val_accuracy: 0.6584
# Epoch 32/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6335 - accuracy: 0.6440 - val_loss: 0.6247 - val_accuracy: 0.6588
# Epoch 33/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6337 - accuracy: 0.6479 - val_loss: 0.6243 - val_accuracy: 0.6600
# Epoch 34/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6351 - accuracy: 0.6439 - val_loss: 0.6240 - val_accuracy: 0.6600
# Epoch 35/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6329 - accuracy: 0.6467 - val_loss: 0.6236 - val_accuracy: 0.6600
# Epoch 36/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6329 - accuracy: 0.6459 - val_loss: 0.6231 - val_accuracy: 0.6619
# Epoch 37/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6320 - accuracy: 0.6512 - val_loss: 0.6228 - val_accuracy: 0.6638
# Epoch 38/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6322 - accuracy: 0.6392 - val_loss: 0.6225 - val_accuracy: 0.6626
# Epoch 39/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6308 - accuracy: 0.6475 - val_loss: 0.6222 - val_accuracy: 0.6630
# Epoch 40/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6323 - accuracy: 0.6482 - val_loss: 0.6220 - val_accuracy: 0.6622
# Epoch 41/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6332 - accuracy: 0.6453 - val_loss: 0.6217 - val_accuracy: 0.6641
# Epoch 42/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6314 - accuracy: 0.6521 - val_loss: 0.6215 - val_accuracy: 0.6638
# Epoch 43/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6296 - accuracy: 0.6492 - val_loss: 0.6213 - val_accuracy: 0.6619
# Epoch 44/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6323 - accuracy: 0.6491 - val_loss: 0.6210 - val_accuracy: 0.6645
# Epoch 45/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6296 - accuracy: 0.6502 - val_loss: 0.6208 - val_accuracy: 0.6645
# Epoch 46/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6297 - accuracy: 0.6516 - val_loss: 0.6208 - val_accuracy: 0.6615
# Epoch 47/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6243 - accuracy: 0.6539 - val_loss: 0.6205 - val_accuracy: 0.6615
# Epoch 48/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6289 - accuracy: 0.6466 - val_loss: 0.6203 - val_accuracy: 0.6630
# Epoch 49/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6276 - accuracy: 0.6565 - val_loss: 0.6201 - val_accuracy: 0.6626
# Epoch 50/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6280 - accuracy: 0.6527 - val_loss: 0.6199 - val_accuracy: 0.6645
# 83/83 [==============================] - 1s 4ms/step
# FOLD 2 ROC-AUC SCORE 0.7131
# Fold 3 시작!
# Epoch 1/100
# 330/330 [==============================] - 5s 8ms/step - loss: 0.6927 - accuracy: 0.5199 - val_loss: 0.6877 - val_accuracy: 0.5556
# Epoch 2/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6892 - accuracy: 0.5364 - val_loss: 0.6834 - val_accuracy: 0.6004
# Epoch 3/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6856 - accuracy: 0.5502 - val_loss: 0.6795 - val_accuracy: 0.6118
# Epoch 4/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6819 - accuracy: 0.5652 - val_loss: 0.6758 - val_accuracy: 0.6167
# Epoch 5/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6782 - accuracy: 0.5782 - val_loss: 0.6722 - val_accuracy: 0.6269
# Epoch 6/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6724 - accuracy: 0.5918 - val_loss: 0.6684 - val_accuracy: 0.6296
# Epoch 7/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6722 - accuracy: 0.5950 - val_loss: 0.6648 - val_accuracy: 0.6315
# Epoch 8/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6665 - accuracy: 0.6017 - val_loss: 0.6612 - val_accuracy: 0.6376
# Epoch 9/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6629 - accuracy: 0.6073 - val_loss: 0.6578 - val_accuracy: 0.6395
# Epoch 10/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6620 - accuracy: 0.6092 - val_loss: 0.6549 - val_accuracy: 0.6421
# Epoch 11/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6584 - accuracy: 0.6212 - val_loss: 0.6521 - val_accuracy: 0.6448
# Epoch 12/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6554 - accuracy: 0.6255 - val_loss: 0.6495 - val_accuracy: 0.6455
# Epoch 13/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6532 - accuracy: 0.6284 - val_loss: 0.6475 - val_accuracy: 0.6455
# Epoch 14/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6488 - accuracy: 0.6337 - val_loss: 0.6455 - val_accuracy: 0.6455
# Epoch 15/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6515 - accuracy: 0.6239 - val_loss: 0.6441 - val_accuracy: 0.6474
# Epoch 16/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6467 - accuracy: 0.6368 - val_loss: 0.6426 - val_accuracy: 0.6493
# Epoch 17/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6450 - accuracy: 0.6349 - val_loss: 0.6413 - val_accuracy: 0.6478
# Epoch 18/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6428 - accuracy: 0.6387 - val_loss: 0.6402 - val_accuracy: 0.6493
# Epoch 19/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6438 - accuracy: 0.6385 - val_loss: 0.6394 - val_accuracy: 0.6501
# Epoch 20/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6408 - accuracy: 0.6372 - val_loss: 0.6384 - val_accuracy: 0.6512
# Epoch 21/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6383 - accuracy: 0.6435 - val_loss: 0.6380 - val_accuracy: 0.6524
# Epoch 22/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6371 - accuracy: 0.6470 - val_loss: 0.6373 - val_accuracy: 0.6531
# Epoch 23/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6377 - accuracy: 0.6392 - val_loss: 0.6365 - val_accuracy: 0.6543
# Epoch 24/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6352 - accuracy: 0.6450 - val_loss: 0.6361 - val_accuracy: 0.6539
# Epoch 25/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6349 - accuracy: 0.6438 - val_loss: 0.6356 - val_accuracy: 0.6554
# Epoch 26/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6377 - accuracy: 0.6445 - val_loss: 0.6352 - val_accuracy: 0.6539
# Epoch 27/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6350 - accuracy: 0.6426 - val_loss: 0.6347 - val_accuracy: 0.6535
# Epoch 28/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6308 - accuracy: 0.6506 - val_loss: 0.6345 - val_accuracy: 0.6543
# Epoch 29/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6335 - accuracy: 0.6464 - val_loss: 0.6341 - val_accuracy: 0.6546
# Epoch 30/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6340 - accuracy: 0.6488 - val_loss: 0.6337 - val_accuracy: 0.6558
# Epoch 31/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6316 - accuracy: 0.6470 - val_loss: 0.6333 - val_accuracy: 0.6543
# Epoch 32/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6307 - accuracy: 0.6536 - val_loss: 0.6328 - val_accuracy: 0.6550
# Epoch 33/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6321 - accuracy: 0.6539 - val_loss: 0.6324 - val_accuracy: 0.6550
# Epoch 34/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6302 - accuracy: 0.6534 - val_loss: 0.6322 - val_accuracy: 0.6539
# Epoch 35/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6319 - accuracy: 0.6508 - val_loss: 0.6319 - val_accuracy: 0.6539
# Epoch 36/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6286 - accuracy: 0.6555 - val_loss: 0.6319 - val_accuracy: 0.6539
# Epoch 37/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6268 - accuracy: 0.6535 - val_loss: 0.6315 - val_accuracy: 0.6550
# Epoch 38/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6277 - accuracy: 0.6557 - val_loss: 0.6313 - val_accuracy: 0.6550
# Epoch 39/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6274 - accuracy: 0.6541 - val_loss: 0.6309 - val_accuracy: 0.6546
# Epoch 40/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6282 - accuracy: 0.6549 - val_loss: 0.6305 - val_accuracy: 0.6543
# Epoch 41/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6274 - accuracy: 0.6551 - val_loss: 0.6305 - val_accuracy: 0.6558
# Epoch 42/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6244 - accuracy: 0.6582 - val_loss: 0.6303 - val_accuracy: 0.6546
# Epoch 43/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6284 - accuracy: 0.6533 - val_loss: 0.6302 - val_accuracy: 0.6520
# Epoch 44/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6271 - accuracy: 0.6552 - val_loss: 0.6301 - val_accuracy: 0.6516
# Epoch 45/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6287 - accuracy: 0.6578 - val_loss: 0.6296 - val_accuracy: 0.6539
# Epoch 46/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6264 - accuracy: 0.6590 - val_loss: 0.6293 - val_accuracy: 0.6535
# Epoch 47/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6264 - accuracy: 0.6569 - val_loss: 0.6289 - val_accuracy: 0.6520
# Epoch 48/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6242 - accuracy: 0.6591 - val_loss: 0.6290 - val_accuracy: 0.6524
# Epoch 49/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6251 - accuracy: 0.6586 - val_loss: 0.6289 - val_accuracy: 0.6528
# Epoch 50/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6234 - accuracy: 0.6614 - val_loss: 0.6288 - val_accuracy: 0.6524
# Epoch 51/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6256 - accuracy: 0.6598 - val_loss: 0.6285 - val_accuracy: 0.6520
# Epoch 52/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6253 - accuracy: 0.6564 - val_loss: 0.6283 - val_accuracy: 0.6520
# 83/83 [==============================] - 0s 1ms/step
# FOLD 3 ROC-AUC SCORE 0.7038
# Fold 4 시작!
# Epoch 1/100
# 330/330 [==============================] - 2s 3ms/step - loss: 0.7003 - accuracy: 0.5089 - val_loss: 0.6867 - val_accuracy: 0.5605
# Epoch 2/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6906 - accuracy: 0.5284 - val_loss: 0.6801 - val_accuracy: 0.5951
# Epoch 3/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6861 - accuracy: 0.5466 - val_loss: 0.6742 - val_accuracy: 0.6065
# Epoch 4/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6829 - accuracy: 0.5534 - val_loss: 0.6686 - val_accuracy: 0.6213
# Epoch 5/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6771 - accuracy: 0.5685 - val_loss: 0.6632 - val_accuracy: 0.6288
# Epoch 6/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6718 - accuracy: 0.5832 - val_loss: 0.6583 - val_accuracy: 0.6361
# Epoch 7/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6666 - accuracy: 0.6041 - val_loss: 0.6538 - val_accuracy: 0.6467
# Epoch 8/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6631 - accuracy: 0.6074 - val_loss: 0.6496 - val_accuracy: 0.6474
# Epoch 9/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6612 - accuracy: 0.6117 - val_loss: 0.6455 - val_accuracy: 0.6543
# Epoch 10/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6569 - accuracy: 0.6175 - val_loss: 0.6423 - val_accuracy: 0.6554
# Epoch 11/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6544 - accuracy: 0.6216 - val_loss: 0.6391 - val_accuracy: 0.6573
# Epoch 12/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6510 - accuracy: 0.6292 - val_loss: 0.6365 - val_accuracy: 0.6558
# Epoch 13/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6500 - accuracy: 0.6231 - val_loss: 0.6340 - val_accuracy: 0.6584
# Epoch 14/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6469 - accuracy: 0.6275 - val_loss: 0.6320 - val_accuracy: 0.6565
# Epoch 15/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6461 - accuracy: 0.6307 - val_loss: 0.6301 - val_accuracy: 0.6645
# Epoch 16/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6442 - accuracy: 0.6336 - val_loss: 0.6284 - val_accuracy: 0.6657
# Epoch 17/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6407 - accuracy: 0.6416 - val_loss: 0.6272 - val_accuracy: 0.6676
# Epoch 18/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6390 - accuracy: 0.6451 - val_loss: 0.6260 - val_accuracy: 0.6657
# Epoch 19/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6400 - accuracy: 0.6387 - val_loss: 0.6252 - val_accuracy: 0.6676
# Epoch 20/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6407 - accuracy: 0.6398 - val_loss: 0.6245 - val_accuracy: 0.6679
# Epoch 21/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6393 - accuracy: 0.6380 - val_loss: 0.6239 - val_accuracy: 0.6683
# Epoch 22/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6378 - accuracy: 0.6474 - val_loss: 0.6232 - val_accuracy: 0.6664
# Epoch 23/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6377 - accuracy: 0.6431 - val_loss: 0.6226 - val_accuracy: 0.6641
# Epoch 24/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6355 - accuracy: 0.6397 - val_loss: 0.6222 - val_accuracy: 0.6653
# Epoch 25/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6390 - accuracy: 0.6380 - val_loss: 0.6222 - val_accuracy: 0.6638
# Epoch 26/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6321 - accuracy: 0.6491 - val_loss: 0.6218 - val_accuracy: 0.6638
# Epoch 27/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6339 - accuracy: 0.6502 - val_loss: 0.6215 - val_accuracy: 0.6645
# Epoch 28/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6339 - accuracy: 0.6483 - val_loss: 0.6214 - val_accuracy: 0.6641
# Epoch 29/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6339 - accuracy: 0.6502 - val_loss: 0.6209 - val_accuracy: 0.6630
# Epoch 30/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6306 - accuracy: 0.6526 - val_loss: 0.6207 - val_accuracy: 0.6634
# Epoch 31/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6303 - accuracy: 0.6539 - val_loss: 0.6201 - val_accuracy: 0.6649
# Epoch 32/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6320 - accuracy: 0.6462 - val_loss: 0.6200 - val_accuracy: 0.6630
# Epoch 33/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6318 - accuracy: 0.6559 - val_loss: 0.6198 - val_accuracy: 0.6634
# Epoch 34/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6309 - accuracy: 0.6496 - val_loss: 0.6196 - val_accuracy: 0.6634
# Epoch 35/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6298 - accuracy: 0.6534 - val_loss: 0.6194 - val_accuracy: 0.6641
# Epoch 36/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6283 - accuracy: 0.6545 - val_loss: 0.6191 - val_accuracy: 0.6649
# Epoch 37/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6275 - accuracy: 0.6543 - val_loss: 0.6188 - val_accuracy: 0.6653
# Epoch 38/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6321 - accuracy: 0.6467 - val_loss: 0.6187 - val_accuracy: 0.6645
# Epoch 39/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6279 - accuracy: 0.6527 - val_loss: 0.6187 - val_accuracy: 0.6638
# Epoch 40/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6287 - accuracy: 0.6486 - val_loss: 0.6186 - val_accuracy: 0.6638
# Epoch 41/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6287 - accuracy: 0.6515 - val_loss: 0.6183 - val_accuracy: 0.6645
# Epoch 42/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6289 - accuracy: 0.6522 - val_loss: 0.6182 - val_accuracy: 0.6664
# 83/83 [==============================] - 0s 1ms/step
# FOLD 4 ROC-AUC SCORE 0.7158
# Fold 5 시작!
# Epoch 1/100
# 330/330 [==============================] - 2s 3ms/step - loss: 0.6974 - accuracy: 0.4980 - val_loss: 0.6910 - val_accuracy: 0.5123
# Epoch 2/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6937 - accuracy: 0.5063 - val_loss: 0.6870 - val_accuracy: 0.5165
# Epoch 3/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6920 - accuracy: 0.5207 - val_loss: 0.6830 - val_accuracy: 0.5321
# Epoch 4/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6890 - accuracy: 0.5339 - val_loss: 0.6795 - val_accuracy: 0.5742
# Epoch 5/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6848 - accuracy: 0.5486 - val_loss: 0.6762 - val_accuracy: 0.5981
# Epoch 6/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6837 - accuracy: 0.5574 - val_loss: 0.6730 - val_accuracy: 0.6220
# Epoch 7/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6807 - accuracy: 0.5712 - val_loss: 0.6697 - val_accuracy: 0.6315
# Epoch 8/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6767 - accuracy: 0.5848 - val_loss: 0.6662 - val_accuracy: 0.6357
# Epoch 9/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6748 - accuracy: 0.5861 - val_loss: 0.6626 - val_accuracy: 0.6383
# Epoch 10/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6715 - accuracy: 0.5953 - val_loss: 0.6590 - val_accuracy: 0.6448
# Epoch 11/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6701 - accuracy: 0.5997 - val_loss: 0.6557 - val_accuracy: 0.6474
# Epoch 12/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6660 - accuracy: 0.6064 - val_loss: 0.6523 - val_accuracy: 0.6505
# Epoch 13/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6644 - accuracy: 0.6061 - val_loss: 0.6491 - val_accuracy: 0.6482
# Epoch 14/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6609 - accuracy: 0.6152 - val_loss: 0.6459 - val_accuracy: 0.6478
# Epoch 15/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6581 - accuracy: 0.6245 - val_loss: 0.6429 - val_accuracy: 0.6493
# Epoch 16/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6575 - accuracy: 0.6241 - val_loss: 0.6403 - val_accuracy: 0.6493
# Epoch 17/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6536 - accuracy: 0.6213 - val_loss: 0.6378 - val_accuracy: 0.6520
# Epoch 18/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6535 - accuracy: 0.6263 - val_loss: 0.6357 - val_accuracy: 0.6524
# Epoch 19/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6496 - accuracy: 0.6289 - val_loss: 0.6338 - val_accuracy: 0.6505
# Epoch 20/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6498 - accuracy: 0.6331 - val_loss: 0.6320 - val_accuracy: 0.6509
# Epoch 21/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6451 - accuracy: 0.6332 - val_loss: 0.6302 - val_accuracy: 0.6501
# Epoch 22/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6460 - accuracy: 0.6331 - val_loss: 0.6287 - val_accuracy: 0.6520
# Epoch 23/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6463 - accuracy: 0.6350 - val_loss: 0.6275 - val_accuracy: 0.6516
# Epoch 24/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6443 - accuracy: 0.6364 - val_loss: 0.6264 - val_accuracy: 0.6520
# Epoch 25/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6437 - accuracy: 0.6393 - val_loss: 0.6254 - val_accuracy: 0.6531
# Epoch 26/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6428 - accuracy: 0.6375 - val_loss: 0.6246 - val_accuracy: 0.6531
# Epoch 27/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6426 - accuracy: 0.6332 - val_loss: 0.6238 - val_accuracy: 0.6558
# Epoch 28/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6383 - accuracy: 0.6445 - val_loss: 0.6231 - val_accuracy: 0.6535
# Epoch 29/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6396 - accuracy: 0.6481 - val_loss: 0.6224 - val_accuracy: 0.6546
# Epoch 30/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6375 - accuracy: 0.6468 - val_loss: 0.6217 - val_accuracy: 0.6546
# Epoch 31/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6405 - accuracy: 0.6368 - val_loss: 0.6211 - val_accuracy: 0.6569
# Epoch 32/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6370 - accuracy: 0.6445 - val_loss: 0.6205 - val_accuracy: 0.6581
# Epoch 33/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6363 - accuracy: 0.6450 - val_loss: 0.6200 - val_accuracy: 0.6596
# Epoch 34/100
# 330/330 [==============================] - 2s 5ms/step - loss: 0.6353 - accuracy: 0.6483 - val_loss: 0.6195 - val_accuracy: 0.6588
# Epoch 35/100
# 330/330 [==============================] - 2s 7ms/step - loss: 0.6359 - accuracy: 0.6458 - val_loss: 0.6191 - val_accuracy: 0.6584
# Epoch 36/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6371 - accuracy: 0.6425 - val_loss: 0.6186 - val_accuracy: 0.6554
# Epoch 37/100
# 330/330 [==============================] - 2s 6ms/step - loss: 0.6351 - accuracy: 0.6475 - val_loss: 0.6182 - val_accuracy: 0.6584
# Epoch 38/100
# 330/330 [==============================] - 1s 4ms/step - loss: 0.6320 - accuracy: 0.6525 - val_loss: 0.6178 - val_accuracy: 0.6577
# Epoch 39/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6357 - accuracy: 0.6460 - val_loss: 0.6174 - val_accuracy: 0.6600
# Epoch 40/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6318 - accuracy: 0.6451 - val_loss: 0.6171 - val_accuracy: 0.6588
# Epoch 41/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6329 - accuracy: 0.6489 - val_loss: 0.6167 - val_accuracy: 0.6603
# Epoch 42/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6341 - accuracy: 0.6467 - val_loss: 0.6164 - val_accuracy: 0.6607
# Epoch 43/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6326 - accuracy: 0.6544 - val_loss: 0.6161 - val_accuracy: 0.6626
# Epoch 44/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6325 - accuracy: 0.6518 - val_loss: 0.6158 - val_accuracy: 0.6645
# Epoch 45/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6316 - accuracy: 0.6510 - val_loss: 0.6155 - val_accuracy: 0.6638
# Epoch 46/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6311 - accuracy: 0.6486 - val_loss: 0.6153 - val_accuracy: 0.6638
# Epoch 47/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6304 - accuracy: 0.6520 - val_loss: 0.6150 - val_accuracy: 0.6641
# Epoch 48/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6313 - accuracy: 0.6483 - val_loss: 0.6148 - val_accuracy: 0.6653
# Epoch 49/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6315 - accuracy: 0.6477 - val_loss: 0.6146 - val_accuracy: 0.6641
# Epoch 50/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6321 - accuracy: 0.6465 - val_loss: 0.6144 - val_accuracy: 0.6653
# Epoch 51/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6467 - val_loss: 0.6142 - val_accuracy: 0.6676
# Epoch 52/100
# 330/330 [==============================] - 1s 2ms/step - loss: 0.6270 - accuracy: 0.6553 - val_loss: 0.6139 - val_accuracy: 0.6664
# Epoch 53/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6275 - accuracy: 0.6540 - val_loss: 0.6137 - val_accuracy: 0.6668
# Epoch 54/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6291 - accuracy: 0.6532 - val_loss: 0.6135 - val_accuracy: 0.6676
# Epoch 55/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6279 - accuracy: 0.6525 - val_loss: 0.6133 - val_accuracy: 0.6668
# Epoch 56/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6283 - accuracy: 0.6542 - val_loss: 0.6131 - val_accuracy: 0.6668
# Epoch 57/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6307 - accuracy: 0.6545 - val_loss: 0.6129 - val_accuracy: 0.6668
# Epoch 58/100
# 330/330 [==============================] - 1s 3ms/step - loss: 0.6287 - accuracy: 0.6519 - val_loss: 0.6128 - val_accuracy: 0.6657
# 83/83 [==============================] - 0s 1ms/step
# FOLD 5 ROC-AUC SCORE 0.7257
# 교차 검증 ROC-AUC 평균 점수 0.7184

# %%
pred = model.predict(test_scaled).ravel()

sub_path = os.path.join(file_path, "데이터셋", "sample_submission.csv")
submission1 = pd.read_csv(sub_path)

submission1["채무 불이행 확률"] = pred * 100
submission1.to_csv("C:/Users/yunju/OneDrive/바탕 화면/submissions/채무불이행 예측/submission(2025-03-18).csv", index = False) 

submission1.head()
# Out:
# 65/65 [==============================] - 0s 1ms/step
#          UID  채무 불이행 확률
# 0  TEST_0000  55.407612
# 1  TEST_0001  49.354431
# 2  TEST_0002  41.225983
# 3  TEST_0003  31.948677
# 4  TEST_0004  48.803303
